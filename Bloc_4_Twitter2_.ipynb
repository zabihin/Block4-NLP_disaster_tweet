# %% [markdown]
# <a href="https://colab.research.google.com/github/zabihin/NLP_disaster_tweet/blob/main/Bloc_4_Twitter2_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Load the data

# %% [markdown]
# ![oie_9LGhBHUTpNS6.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ###Importing Libraries

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import numpy as np

import spacy
nlp = spacy.load('en_core_web_sm')
from spacy.lang.en.stop_words import STOP_WORDS

import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Bidirectional, Dropout, SimpleRNN, GRU
from tensorflow.keras.optimizers import Adam

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

from tensorflow.keras.callbacks import ModelCheckpoint

from termcolor import colored

from sklearn.model_selection import train_test_split

# %%
#load data
train_tweet = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/train.csv')

test_tweet = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/test.csv')

display (train_tweet.head())
print (train_tweet.shape)
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
# (7613, 5)

# %% [markdown]
# ##Data Cleaning

# %%
train_tweet.drop(['id','keyword','location'],axis=1,inplace=True)

# %% [markdown]
# find that if the same twitt have differenet target?

# %%
#find if there are same tweets with different targets
train_tweet['index_t'] = train_tweet.index # make list of originals index

aggs = {'target': 'mean',
         'index_t':lambda x: list(x)} # Keep track of the index 
grouped_df = train_tweet[train_tweet['text'].duplicated(keep=False)].groupby('text').agg(aggs) 

# if target mean is not equal to 0 or 1 --> we have same tweets with different targets
dif_targets = grouped_df[(grouped_df.target!=1) & (grouped_df.target!=0)].reset_index()
dif_targets
# Out:
#                                                  text    target  \
# 0   #Allah describes piling up #wealth thinking it...  0.333333
# 1   #foodscare #offers2go #NestleIndia slips into ...  0.666667
# 2   .POTUS #StrategicPatience is a strategy for #G...  0.750000
# 3   CLEARED:incident with injury:I-495  inner loop...  0.666667
# 4   Caution: breathing may be hazardous to your he...  0.500000
# 5   He came to a land which was engulfed in tribal...  0.333333
# 6   Hellfire is surrounded by desires so be carefu...  0.333333
# 7   Hellfire! We donÛªt even want to think about ...  0.500000
# 8   I Pledge Allegiance To The P.O.P.E. And The Bu...  0.500000
# 9   In #islam saving a person is equal in reward t...  0.500000
# 10  Mmmmmm I'm burning.... I'm burning buildings I...  0.500000
# 11  RT NotExplained: The only known image of infam...  0.500000
# 12  The Prophet (peace be upon him) said 'Save you...  0.333333
# 13                         To fight bioterrorism sir.  0.500000
# 14  Who is bringing the tornadoes and floods. Who ...  0.333333
# 15  like for the music video I want some real acti...  0.500000
# 16  that horrible sinking feeling when youÛªve be...  0.500000
# 17  wowo--=== 12000 Nigerian refugees repatriated ...  0.500000
#
#                                  index_t
# 0                     [4290, 4299, 4312]
# 1                     [4221, 4239, 4244]
# 2               [2830, 2831, 2832, 2833]
# 3                     [4597, 4605, 4618]
# 4                           [4232, 4235]
# 5   [3240, 3243, 3248, 3251, 3261, 3266]
# 6                     [4285, 4305, 4313]
# 7                           [4306, 4320]
# 8                           [1214, 1365]
# 9                           [6614, 6616]
# 10                          [1197, 1331]
# 11                          [4379, 4381]
# 12  [4284, 4286, 4292, 4304, 4309, 4318]
# 13                  [610, 624, 630, 634]
# 14                    [3985, 4013, 4019]
# 15                          [1221, 1349]
# 16              [6091, 6094, 6103, 6123]
# 17                          [5620, 5641]

# %% [markdown]
# so if the mean of target for same tweets is greater than 0.5 I change all of targets to 1, if the mean is less than 0.5 I change it to 0 and  i remove the tweets if the mean =0.5
# then I remove repeated tweets and  do re index

# %%
for ind in range(len(dif_targets.index)):
  if dif_targets.target[ind]>0.5:
    for l in dif_targets.index_t[ind]:
      train_tweet.target[l]=1
  elif dif_targets.target[ind]<0.5: 
    for l in dif_targets.index_t[ind]:
      train_tweet.target[l]=0
  else:
    train_tweet.drop(dif_targets.index_t[ind],inplace=True)
 

train_tweet.drop_duplicates(keep='first',inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
train_tweet.shape
# Out:
# (7589, 3)

# %% [markdown]
# #clean text

# %%
# Function to clean the text
def clean_text(text):
    # remove punctuation
    text = ''.join([c for c in text if c not in r"[!\"#@$%&()'‰ûª*+,-./:;<=>?[\\\]^_`{|}~]+"]) 
    # remove stopwords
    text = ' '.join([c for c in text.split() if c not in STOP_WORDS])
    # remove numbers
    text = ''.join([c for c in text if not c.isdigit()])
    # lowercase
    text = ' '.join(text.split()).lower()
    # lemmatize
    text = ' '.join([c.lemma_ for c in nlp(text)])
    # remove words starting by http
    text = ' '.join([c for c in text.split() if not c.startswith("http")])
    
    return text

# %%
train_tweet["text_clean"] = train_tweet["text"].apply(clean_text)

# %% [markdown]
# ##Tokenization and Padding ckeaned text

# %%
# Creation of a tokenizer
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=10000)

# Training the tokenizer on the training set
tokenizer.fit_on_texts(train_tweet['text_clean'])

# Transform the text into sequences of integers
train_tweet["text_encoded"] = tokenizer.texts_to_sequences(train_tweet["text_clean"])

# %%
#preprosses test
test_tweet["text_clean"] = test_tweet["text"].apply(clean_text)

test_tweet["text_encoded"] = tokenizer.texts_to_sequences(test_tweet["text_clean"])

# %%
# get the max length for padding
dataframes = [train_tweet,test_tweet]
max_pad = max([max(df['text_encoded'].apply(lambda x: len(x))) for df in dataframes])

# %%
text_pad_train = tf.keras.preprocessing.sequence.pad_sequences(train_tweet["text_encoded"], padding="post", maxlen=max_pad)
text_pad_test = tf.keras.preprocessing.sequence.pad_sequences(test_tweet["text_encoded"], padding="post", maxlen=max_pad)

# %%
train_tweet.reset_index(drop=True, inplace=True)
train_tweet.tail()
# Out:
#                                                    text  target  index_t  \
# 7584  Two giant cranes holding a bridge collapse int...       1     7608
# 7585  @aria_ahrary @TheTawniest The out of control w...       1     7609
# 7586  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...       1     7610
# 7587  Police investigating after an e-bike collided ...       1     7611
# 7588  The Latest: More Homes Razed by Northern Calif...       1     7612
#
#                                              text_clean  \
# 7584   two giant crane hold bridge collapse nearby home
# 7585  ariaahrary thetawniest the control wild fire c...
# 7586                           m utckm s volcano hawaii
# 7587  police investigate ebike collided car little p...
# 7588  the late more home raze northern california wi...
#
#                                            text_encoded
# 7584            [289, 696, 1015, 382, 303, 55, 553, 39]
# 7585  [5471, 5472, 2, 605, 270, 6, 51, 170, 232, 173...
# 7586                           [7, 3472, 11, 469, 1331]
# 7587  [34, 801, 2631, 2632, 58, 254, 4324, 2631, 161...
# 7588      [2, 144, 111, 39, 425, 170, 51, 104, 525, 17]

# %%
# Train test split
X_train, X_val, y_train, y_val = train_test_split(text_pad_train, train_tweet["target"], test_size=0.3)

# Turns dataframe into tensors
train = tf.data.Dataset.from_tensor_slices((X_train, y_train))
val = tf.data.Dataset.from_tensor_slices((X_val, y_val))

vocab_size = tokenizer.num_words # the number of words in the vocabulary

# %% [markdown]
# #RNN

# %%
# Define a text classifier model
model_RNN = tf.keras.Sequential([
    Embedding(input_dim=vocab_size, output_dim=8, input_shape=[max_pad,]),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(1, activation='sigmoid')  # Binary classification between 0 and 1
])

model_RNN.compile(
    loss='binary_crossentropy',
    optimizer=Adam(learning_rate=0.001),
    metrics=['accuracy']
)

checkpoint = ModelCheckpoint("model/RNN_analysis.h5", monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto') 

model_RNN.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 28, 8)             80000
#
#  global_average_pooling1d (G  (None, 8)                0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 16)                144
#
#  dropout (Dropout)           (None, 16)                0
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 80,161
# Trainable params: 80,161
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Trains the model
history = model_RNN.fit(
    np.array(X_train), #must convert to numpy array before sending to model
    np.array(y_train), #must convert to numpy array before sending to model
    epochs=15, 
    batch_size=64,
    validation_data=(X_val, y_val),
    callbacks = [checkpoint])
# Out:
# Epoch 1/15
# 65/83 [======================>.......] - ETA: 0s - loss: 0.6852 - accuracy: 0.5649
# Epoch 1: val_accuracy improved from -inf to 0.57927, saving model to model/RNN_analysis.h5
# 83/83 [==============================] - 5s 6ms/step - loss: 0.6837 - accuracy: 0.5653 - val_loss: 0.6749 - val_accuracy: 0.5793
# Epoch 2/15
# 65/83 [======================>.......] - ETA: 0s - loss: 0.6724 - accuracy: 0.5712
# Epoch 2: val_accuracy did not improve from 0.57927
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6708 - accuracy: 0.5676 - val_loss: 0.6607 - val_accuracy: 0.5793
# Epoch 3/15
# 65/83 [======================>.......] - ETA: 0s - loss: 0.6454 - accuracy: 0.5969
# Epoch 3: val_accuracy improved from 0.57927 to 0.67765, saving model to model/RNN_analysis.h5
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6414 - accuracy: 0.6037 - val_loss: 0.6251 - val_accuracy: 0.6776
# Epoch 4/15
# 65/83 [======================>.......] - ETA: 0s - loss: 0.5933 - accuracy: 0.7221
# Epoch 4: val_accuracy improved from 0.67765 to 0.73869, saving model to model/RNN_analysis.h5
# 83/83 [==============================] - 0s 4ms/step - loss: 0.5842 - accuracy: 0.7257 - val_loss: 0.5728 - val_accuracy: 0.7387
# Epoch 5/15
# 64/83 [======================>.......] - ETA: 0s - loss: 0.5229 - accuracy: 0.8000
# Epoch 5: val_accuracy improved from 0.73869 to 0.78876, saving model to model/RNN_analysis.h5
# 83/83 [==============================] - 0s 4ms/step - loss: 0.5100 - accuracy: 0.8102 - val_loss: 0.5183 - val_accuracy: 0.7888
# Epoch 6/15
# 65/83 [======================>.......] - ETA: 0s - loss: 0.4439 - accuracy: 0.8438
# Epoch 6: val_accuracy improved from 0.78876 to 0.81247, saving model to model/RNN_analysis.h5
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4388 - accuracy: 0.8449 - val_loss: 0.4805 - val_accuracy: 0.8125
# Epoch 7/15
# 64/83 [======================>.......] - ETA: 0s - loss: 0.3918 - accuracy: 0.8635
# Epoch 7: val_accuracy did not improve from 0.81247
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3839 - accuracy: 0.8652 - val_loss: 0.4580 - val_accuracy: 0.8090
# Epoch 8/15
# 64/83 [======================>.......] - ETA: 0s - loss: 0.3426 - accuracy: 0.8772
# Epoch 8: val_accuracy improved from 0.81247 to 0.81730, saving model to model/RNN_analysis.h5
# 83/83 [==============================] - 0s 4ms/step - loss: 0.3406 - accuracy: 0.8782 - val_loss: 0.4471 - val_accuracy: 0.8173
# Epoch 9/15
# 64/83 [======================>.......] - ETA: 0s - loss: 0.3071 - accuracy: 0.8879
# Epoch 9: val_accuracy improved from 0.81730 to 0.81774, saving model to model/RNN_analysis.h5
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3072 - accuracy: 0.8869 - val_loss: 0.4431 - val_accuracy: 0.8177
# Epoch 10/15
# 66/83 [======================>.......] - ETA: 0s - loss: 0.2690 - accuracy: 0.9070
# Epoch 10: val_accuracy did not improve from 0.81774
# 83/83 [==============================] - 0s 3ms/step - loss: 0.2758 - accuracy: 0.9053 - val_loss: 0.4452 - val_accuracy: 0.8129
# Epoch 11/15
# 65/83 [======================>.......] - ETA: 0s - loss: 0.2577 - accuracy: 0.9082
# Epoch 11: val_accuracy did not improve from 0.81774
# 83/83 [==============================] - 0s 3ms/step - loss: 0.2549 - accuracy: 0.9087 - val_loss: 0.4495 - val_accuracy: 0.8138
# Epoch 12/15
# 79/83 [===========================>..] - ETA: 0s - loss: 0.2319 - accuracy: 0.9163
# Epoch 12: val_accuracy did not improve from 0.81774
# 83/83 [==============================] - 0s 4ms/step - loss: 0.2321 - accuracy: 0.9164 - val_loss: 0.4587 - val_accuracy: 0.8037
# Epoch 13/15
# 65/83 [======================>.......] - ETA: 0s - loss: 0.2133 - accuracy: 0.9260
# Epoch 13: val_accuracy did not improve from 0.81774
# 83/83 [==============================] - 0s 3ms/step - loss: 0.2148 - accuracy: 0.9266 - val_loss: 0.4671 - val_accuracy: 0.8006
# Epoch 14/15
# 64/83 [======================>.......] - ETA: 0s - loss: 0.1934 - accuracy: 0.9373
# Epoch 14: val_accuracy did not improve from 0.81774
# 83/83 [==============================] - 0s 3ms/step - loss: 0.1964 - accuracy: 0.9341 - val_loss: 0.4760 - val_accuracy: 0.8032
# Epoch 15/15
# 76/83 [==========================>...] - ETA: 0s - loss: 0.1813 - accuracy: 0.9406
# Epoch 15: val_accuracy did not improve from 0.81774
# 83/83 [==============================] - 0s 4ms/step - loss: 0.1810 - accuracy: 0.9409 - val_loss: 0.4909 - val_accuracy: 0.7931

# %%
# Plot the accuracy and validation accuracy
fig = go.Figure(data=[
                      go.Scatter(
                          y=history.history["accuracy"],
                          name="accuracy",
                          mode="lines",),
                      go.Scatter(
                          y=history.history["val_accuracy"],
                          name="val_accuracy",
                          mode="lines")
])

fig.update_layout(
    title='Accuracy and Validation Accuracy by Epoch',
    xaxis_title='epochs',
    yaxis_title='',
    yaxis=dict(range=[0, 1])

)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d6f7e568-24f9-4d89-bc34-77a6ac008442" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d6f7e568-24f9-4d89-bc34-77a6ac008442")) {                    Plotly.newPlot(                        "d6f7e568-24f9-4d89-bc34-77a6ac008442",                        [{"mode":"lines","name":"accuracy","y":[0.5653237700462341,0.5675828456878662,0.603727400302887,0.7257153391838074,0.8102409839630127,0.8448795080184937,0.8652108311653137,0.8782002925872803,0.8868599534034729,0.905308723449707,0.9086973071098328,0.9164156913757324,0.9265813231468201,0.9341114163398743,0.9408885836601257],"type":"scatter"},{"mode":"lines","name":"val_accuracy","y":[0.5792709589004517,0.5792709589004517,0.6776460409164429,0.7386912703514099,0.7887571454048157,0.8124725222587585,0.8089591860771179,0.817303478717804,0.817742645740509,0.8129117488861084,0.8137900829315186,0.8036890625953674,0.8006148338317871,0.8032498955726624,0.7931488752365112],"type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]," ...

# %%
# Prediction
test_tweet['model_preds'] = model_RNN.predict(text_pad_test)
test_tweet['target'] = test_tweet['model_preds'].apply(lambda x: 1 if x >= 0.5 else 0)
display(test_tweet.head())
# Out:
#    id keyword location                                               text  \
# 0   0     NaN      NaN                 Just happened a terrible car crash
# 1   2     NaN      NaN  Heard about #earthquake is different cities, s...
# 2   3     NaN      NaN  there is a forest fire at spot pond, geese are...
# 3   9     NaN      NaN           Apocalypse lighting. #Spokane #wildfires
# 4  11     NaN      NaN      Typhoon Soudelor kills 28 in China and Taiwan
#
#                                        text_clean  \
# 0                  just happen terrible car crash
# 1        hear earthquake different city stay safe
# 2  forest fire spot pond geese flee street I save
# 3            apocalypse lighting spokane wildfire
# 4              typhoon soudelor kill china taiwan
#
#                              text_encoded  model_preds  target
# 0                [202, 217, 1628, 58, 24]     0.791096       1
# 1        [153, 216, 1016, 178, 412, 1202]     0.712363       1
# 2  [157, 6, 592, 2862, 2185, 445, 1, 148]     0.952990       1
# 3                  [391, 3168, 5935, 104]     0.814450       1
# 4               [457, 574, 21, 400, 1020]     0.974027       1

# %%
# Create a submission file for Kaggle
submission = test_tweet[["id", "target"]]

# Save the submission file
submission.to_csv("submission_RNN.csv", index=False, header=True)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #LSTM

# %%
# Defines a text classifier model
model_lstm = tf.keras.Sequential([
    Embedding(input_dim=vocab_size, output_dim=8, input_shape=[max_pad,]),
    LSTM(units=64, return_sequences=True),
    LSTM(units=32, return_sequences=False), 
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(1, activation='sigmoid')  
])

model_lstm.compile(
    loss='binary_crossentropy',
    optimizer=Adam(learning_rate=0.001),
    metrics=['accuracy']
)

checkpoint = ModelCheckpoint("model/lstm.h5", monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto') 

model_lstm.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 28, 8)             80000
#
#  lstm (LSTM)                 (None, 28, 64)            18688
#
#  lstm_1 (LSTM)               (None, 32)                12416
#
#  dense_2 (Dense)             (None, 16)                528
#
#  dropout_1 (Dropout)         (None, 16)                0
#
#  dense_3 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 111,649
# Trainable params: 111,649
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Trains the model
history_lstm = model_lstm.fit(
    np.array(X_train), #must convert to numpy array before sending to model
    np.array(y_train), #must convert to numpy array before sending to model
    epochs=15, 
    batch_size=64,
    validation_data=(X_val, y_val),
    callbacks = [checkpoint])
# Out:
# Epoch 1/15
# 77/83 [==========================>...] - ETA: 0s - loss: 0.6475 - accuracy: 0.6116
# Epoch 1: val_accuracy improved from -inf to 0.78085, saving model to model/lstm.h5
# 83/83 [==============================] - 5s 16ms/step - loss: 0.6390 - accuracy: 0.6226 - val_loss: 0.4893 - val_accuracy: 0.7809
# Epoch 2/15
# 81/83 [============================>.] - ETA: 0s - loss: 0.4065 - accuracy: 0.8362
# Epoch 2: val_accuracy improved from 0.78085 to 0.79886, saving model to model/lstm.h5
# 83/83 [==============================] - 1s 7ms/step - loss: 0.4047 - accuracy: 0.8373 - val_loss: 0.4547 - val_accuracy: 0.7989
# Epoch 3/15
# 81/83 [============================>.] - ETA: 0s - loss: 0.2711 - accuracy: 0.9018
# Epoch 3: val_accuracy did not improve from 0.79886
# 83/83 [==============================] - 1s 7ms/step - loss: 0.2697 - accuracy: 0.9021 - val_loss: 0.5726 - val_accuracy: 0.7664
# Epoch 4/15
# 81/83 [============================>.] - ETA: 0s - loss: 0.2050 - accuracy: 0.9317
# Epoch 4: val_accuracy did not improve from 0.79886
# 83/83 [==============================] - 1s 7ms/step - loss: 0.2045 - accuracy: 0.9324 - val_loss: 0.5513 - val_accuracy: 0.7756
# Epoch 5/15
# 77/83 [==========================>...] - ETA: 0s - loss: 0.1473 - accuracy: 0.9541
# Epoch 5: val_accuracy did not improve from 0.79886
# 83/83 [==============================] - 1s 7ms/step - loss: 0.1478 - accuracy: 0.9541 - val_loss: 0.7925 - val_accuracy: 0.7721
# Epoch 6/15
# 81/83 [============================>.] - ETA: 0s - loss: 0.1156 - accuracy: 0.9649
# Epoch 6: val_accuracy did not improve from 0.79886
# 83/83 [==============================] - 1s 7ms/step - loss: 0.1155 - accuracy: 0.9650 - val_loss: 0.6833 - val_accuracy: 0.7765
# Epoch 7/15
# 79/83 [===========================>..] - ETA: 0s - loss: 0.1050 - accuracy: 0.9678
# Epoch 7: val_accuracy did not improve from 0.79886
# 83/83 [==============================] - 1s 7ms/step - loss: 0.1053 - accuracy: 0.9680 - val_loss: 0.8719 - val_accuracy: 0.7734
# Epoch 8/15
# 81/83 [============================>.] - ETA: 0s - loss: 0.0977 - accuracy: 0.9707
# Epoch 8: val_accuracy did not improve from 0.79886
# 83/83 [==============================] - 1s 7ms/step - loss: 0.0986 - accuracy: 0.9706 - val_loss: 0.8845 - val_accuracy: 0.7606
# Epoch 9/15
# 81/83 [============================>.] - ETA: 0s - loss: 0.0886 - accuracy: 0.9765
# Epoch 9: val_accuracy did not improve from 0.79886
# 83/83 [==============================] - 1s 7ms/step - loss: 0.0882 - accuracy: 0.9765 - val_loss: 0.7621 - val_accuracy: 0.7747
# Epoch 10/15
# 81/83 [============================>.] - ETA: 0s - loss: 0.0811 - accuracy: 0.9757
# Epoch 10: val_accuracy did not improve from 0.79886
# 83/83 [==============================] - 1s 7ms/step - loss: 0.0854 - accuracy: 0.9750 - val_loss: 0.7366 - val_accuracy: 0.7721
# Epoch 11/15
# 81/83 [============================>.] - ETA: 0s - loss: 0.0756 - accuracy: 0.9803
# Epoch 11: val_accuracy did not improve from 0.79886
# 83/83 [==============================] - 1s 7ms/step - loss: 0.0752 - accuracy: 0.9806 - val_loss: 0.8573 - val_accuracy: 0.7743
# Epoch 12/15
# 81/83 [============================>.] - ETA: 0s - loss: 0.0707 - accuracy: 0.9780
# Epoch 12: val_accuracy did not improve from 0.79886
# 83/83 [==============================] - 1s 7ms/step - loss: 0.0720 - accuracy: 0.9780 - val_loss: 0.9868 - val_accuracy: 0.7668
# Epoch 13/15
# 81/83 [============================>.] - ETA: 0s - loss: 0.0656 - accuracy: 0.9805
# Epoch 13: val_accuracy did not improve from 0.79886
# 83/83 [==============================] - 1s 7ms/step - loss: 0.0650 - accuracy: 0.9806 - val_loss: 0.9811 - val_accuracy: 0.7628
# Epoch 14/15
# 81/83 [============================>.] - ETA: 0s - loss: 0.0682 - accuracy: 0.9807
# Epoch 14: val_accuracy did not improve from 0.79886
# 83/83 [==============================] - 1s 7ms/step - loss: 0.0673 - accuracy: 0.9810 - val_loss: 0.9879 - val_accuracy: 0.7721
# Epoch 15/15
# 81/83 [============================>.] - ETA: 0s - loss: 0.0631 - accuracy: 0.9834
# Epoch 15: val_accuracy did not improve from 0.79886
# 83/83 [==============================] - 1s 7ms/step - loss: 0.0623 - accuracy: 0.9834 - val_loss: 1.0795 - val_accuracy: 0.7633

# %%
# Plot the accuracy and validation accuracy
fig = go.Figure(data=[
                      go.Scatter(
                          y=history_lstm.history["accuracy"],
                          name="accuracy",
                          mode="lines",),
                      go.Scatter(
                          y=history_lstm.history["val_accuracy"],
                          name="val_accuracy",
                          mode="lines")
])

fig.update_layout(
    title='Accuracy and Validation Accuracy by Epoch',
    xaxis_title='epochs',
    yaxis_title='',
    yaxis=dict(range=[0, 1])

)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c72cbf26-6ab8-45e8-9ef3-48c767129737" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c72cbf26-6ab8-45e8-9ef3-48c767129737")) {                    Plotly.newPlot(                        "c72cbf26-6ab8-45e8-9ef3-48c767129737",                        [{"mode":"lines","name":"accuracy","y":[0.6225526928901672,0.8373494148254395,0.9021084308624268,0.9324171543121338,0.954066276550293,0.9649849534034729,0.9679970145225525,0.9706325531005859,0.9764683842658997,0.9749623537063599,0.9806099534034729,0.9779744148254395,0.9806099534034729,0.9809864163398743,0.983433723449707],"type":"scatter"},{"mode":"lines","name":"val_accuracy","y":[0.7808520197868347,0.7988581657409668,0.766359269618988,0.7755818963050842,0.7720685005187988,0.7764602303504944,0.7733860611915588,0.7606499791145325,0.7747035622596741,0.7720685005187988,0.774264395236969,0.7667984366416931,0.7628458738327026,0.7720685005187988,0.7632850408554077],"type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]," ...

# %%
# Prediction
test_tweet['model_preds'] = model_lstm.predict(text_pad_test)
test_tweet['target'] = test_tweet['model_preds'].apply(lambda x: 1 if x >= 0.5 else 0)
display(test_tweet.head())
# Out:
#    id keyword location                                               text  \
# 0   0     NaN      NaN                 Just happened a terrible car crash
# 1   2     NaN      NaN  Heard about #earthquake is different cities, s...
# 2   3     NaN      NaN  there is a forest fire at spot pond, geese are...
# 3   9     NaN      NaN           Apocalypse lighting. #Spokane #wildfires
# 4  11     NaN      NaN      Typhoon Soudelor kills 28 in China and Taiwan
#
#                                        text_clean  \
# 0                  just happen terrible car crash
# 1        hear earthquake different city stay safe
# 2  forest fire spot pond geese flee street I save
# 3            apocalypse lighting spokane wildfire
# 4              typhoon soudelor kill china taiwan
#
#                              text_encoded  model_preds  target
# 0                [202, 217, 1628, 58, 24]     0.996439       1
# 1        [153, 216, 1016, 178, 412, 1202]     0.003025       0
# 2  [157, 6, 592, 2862, 2185, 445, 1, 148]     0.999963       1
# 3                  [391, 3168, 5935, 104]     0.300262       0
# 4               [457, 574, 21, 400, 1020]     0.999963       1

# %%
# Create a submission file for Kaggle
submission = test_tweet[["id", "target"]]

# Save the submission file
submission.to_csv("submission_LSTM.csv", index=False, header=True)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #GRU

# %%
# Defines a text classifier model
model_gru = tf.keras.Sequential([
    Embedding(input_dim=vocab_size, output_dim=8, input_shape=[max_pad,]),
    GRU(units=64, return_sequences=True),
    GRU(units=32, return_sequences=False), 
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(1, activation='sigmoid')  
])

model_gru.compile(
    loss='binary_crossentropy',
    optimizer=Adam(learning_rate=0.001),
    metrics=['accuracy']
)

checkpoint = ModelCheckpoint("model/gru.h5", monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto') 

model_gru.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 28, 8)             80000
#
#  gru (GRU)                   (None, 28, 64)            14208
#
#  gru_1 (GRU)                 (None, 32)                9408
#
#  dense_4 (Dense)             (None, 16)                528
#
#  dropout_2 (Dropout)         (None, 16)                0
#
#  dense_5 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 104,161
# Trainable params: 104,161
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Trains the model
history_gru= model_gru.fit(
    np.array(X_train), #must convert to numpy array before sending to model
    np.array(y_train), #must convert to numpy array before sending to model
    epochs=15, 
    batch_size=64,
    validation_data=(X_val, y_val),
    callbacks = [checkpoint])
# Out:
# Epoch 1/15
# 80/83 [===========================>..] - ETA: 0s - loss: 0.6867 - accuracy: 0.5631
# Epoch 1: val_accuracy improved from -inf to 0.57927, saving model to model/gru.h5
# 83/83 [==============================] - 4s 18ms/step - loss: 0.6872 - accuracy: 0.5616 - val_loss: 0.6809 - val_accuracy: 0.5793
# Epoch 2/15
# 76/83 [==========================>...] - ETA: 0s - loss: 0.6855 - accuracy: 0.5676
# Epoch 2: val_accuracy did not improve from 0.57927
# 83/83 [==============================] - 1s 7ms/step - loss: 0.6854 - accuracy: 0.5676 - val_loss: 0.6806 - val_accuracy: 0.5793
# Epoch 3/15
# 81/83 [============================>.] - ETA: 0s - loss: 0.6480 - accuracy: 0.6163
# Epoch 3: val_accuracy improved from 0.57927 to 0.77866, saving model to model/gru.h5
# 83/83 [==============================] - 1s 7ms/step - loss: 0.6432 - accuracy: 0.6209 - val_loss: 0.4885 - val_accuracy: 0.7787
# Epoch 4/15
# 81/83 [============================>.] - ETA: 0s - loss: 0.3958 - accuracy: 0.8412
# Epoch 4: val_accuracy improved from 0.77866 to 0.79095, saving model to model/gru.h5
# 83/83 [==============================] - 1s 7ms/step - loss: 0.3952 - accuracy: 0.8415 - val_loss: 0.4595 - val_accuracy: 0.7910
# Epoch 5/15
# 81/83 [============================>.] - ETA: 0s - loss: 0.2886 - accuracy: 0.8968
# Epoch 5: val_accuracy improved from 0.79095 to 0.79754, saving model to model/gru.h5
# 83/83 [==============================] - 1s 7ms/step - loss: 0.2880 - accuracy: 0.8966 - val_loss: 0.4651 - val_accuracy: 0.7975
# Epoch 6/15
# 81/83 [============================>.] - ETA: 0s - loss: 0.2262 - accuracy: 0.9252
# Epoch 6: val_accuracy did not improve from 0.79754
# 83/83 [==============================] - 1s 7ms/step - loss: 0.2237 - accuracy: 0.9258 - val_loss: 0.5617 - val_accuracy: 0.7905
# Epoch 7/15
# 81/83 [============================>.] - ETA: 0s - loss: 0.1799 - accuracy: 0.9470
# Epoch 7: val_accuracy did not improve from 0.79754
# 83/83 [==============================] - 1s 7ms/step - loss: 0.1793 - accuracy: 0.9475 - val_loss: 0.5071 - val_accuracy: 0.7813
# Epoch 8/15
# 78/83 [===========================>..] - ETA: 0s - loss: 0.1540 - accuracy: 0.9567
# Epoch 8: val_accuracy did not improve from 0.79754
# 83/83 [==============================] - 1s 7ms/step - loss: 0.1567 - accuracy: 0.9554 - val_loss: 0.5656 - val_accuracy: 0.7892
# Epoch 9/15
# 81/83 [============================>.] - ETA: 0s - loss: 0.1340 - accuracy: 0.9608
# Epoch 9: val_accuracy did not improve from 0.79754
# 83/83 [==============================] - 1s 7ms/step - loss: 0.1339 - accuracy: 0.9605 - val_loss: 0.6391 - val_accuracy: 0.7896
# Epoch 10/15
# 80/83 [===========================>..] - ETA: 0s - loss: 0.1076 - accuracy: 0.9678
# Epoch 10: val_accuracy did not improve from 0.79754
# 83/83 [==============================] - 1s 7ms/step - loss: 0.1070 - accuracy: 0.9678 - val_loss: 0.8021 - val_accuracy: 0.7738
# Epoch 11/15
# 81/83 [============================>.] - ETA: 0s - loss: 0.0949 - accuracy: 0.9745
# Epoch 11: val_accuracy did not improve from 0.79754
# 83/83 [==============================] - 1s 7ms/step - loss: 0.0952 - accuracy: 0.9744 - val_loss: 0.7223 - val_accuracy: 0.7457
# Epoch 12/15
# 81/83 [============================>.] - ETA: 0s - loss: 0.0917 - accuracy: 0.9757
# Epoch 12: val_accuracy did not improve from 0.79754
# 83/83 [==============================] - 1s 7ms/step - loss: 0.0926 - accuracy: 0.9753 - val_loss: 0.8035 - val_accuracy: 0.7839
# Epoch 13/15
# 81/83 [============================>.] - ETA: 0s - loss: 0.0827 - accuracy: 0.9784
# Epoch 13: val_accuracy did not improve from 0.79754
# 83/83 [==============================] - 1s 7ms/step - loss: 0.0822 - accuracy: 0.9787 - val_loss: 0.8445 - val_accuracy: 0.7554
# Epoch 14/15
# 81/83 [============================>.] - ETA: 0s - loss: 0.0782 - accuracy: 0.9790
# Epoch 14: val_accuracy did not improve from 0.79754
# 83/83 [==============================] - 1s 7ms/step - loss: 0.0791 - accuracy: 0.9784 - val_loss: 0.9260 - val_accuracy: 0.7782
# Epoch 15/15
# 81/83 [============================>.] - ETA: 0s - loss: 0.0779 - accuracy: 0.9790
# Epoch 15: val_accuracy did not improve from 0.79754
# 83/83 [==============================] - 1s 7ms/step - loss: 0.0769 - accuracy: 0.9795 - val_loss: 0.8777 - val_accuracy: 0.7633

# %%
# Plot the accuracy and validation accuracy
fig = go.Figure(data=[
                      go.Scatter(
                          y=history_gru.history["accuracy"],
                          name="accuracy",
                          mode="lines",),
                      go.Scatter(
                          y=history_gru.history["val_accuracy"],
                          name="val_accuracy",
                          mode="lines")
])

fig.update_layout(
    title='Accuracy and Validation Accuracy by Epoch',
    xaxis_title='epochs',
    yaxis_title='',
    yaxis=dict(range=[0, 1])

)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="98d85e25-c413-4b60-abb7-a8c852cfd52c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("98d85e25-c413-4b60-abb7-a8c852cfd52c")) {                    Plotly.newPlot(                        "98d85e25-c413-4b60-abb7-a8c852cfd52c",                        [{"mode":"lines","name":"accuracy","y":[0.561558723449707,0.5675828456878662,0.6208584308624268,0.8414909839630127,0.8966491222381592,0.9258283376693726,0.947477400302887,0.9553840160369873,0.9604668617248535,0.967808723449707,0.974397599697113,0.975338876247406,0.978727400302887,0.9783508777618408,0.9794804453849792],"type":"scatter"},{"mode":"lines","name":"val_accuracy","y":[0.5792709589004517,0.5792709589004517,0.7786561250686646,0.7909529805183411,0.7975406050682068,0.790513813495636,0.7812911868095398,0.7891963124275208,0.7896354794502258,0.7738252282142639,0.7457180619239807,0.7839261889457703,0.7553799152374268,0.7782169580459595,0.7632850408554077],"type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"typ ...

# %%
# Prediction
test_tweet['model_preds'] = model_gru.predict(text_pad_test)
test_tweet['target'] = test_tweet['model_preds'].apply(lambda x: 1 if x >= 0.5 else 0)
display(test_tweet.head())
# Out:
#    id keyword location                                               text  \
# 0   0     NaN      NaN                 Just happened a terrible car crash
# 1   2     NaN      NaN  Heard about #earthquake is different cities, s...
# 2   3     NaN      NaN  there is a forest fire at spot pond, geese are...
# 3   9     NaN      NaN           Apocalypse lighting. #Spokane #wildfires
# 4  11     NaN      NaN      Typhoon Soudelor kills 28 in China and Taiwan
#
#                                        text_clean  \
# 0                  just happen terrible car crash
# 1        hear earthquake different city stay safe
# 2  forest fire spot pond geese flee street I save
# 3            apocalypse lighting spokane wildfire
# 4              typhoon soudelor kill china taiwan
#
#                              text_encoded  model_preds  target
# 0                [202, 217, 1628, 58, 24]     0.983554       1
# 1        [153, 216, 1016, 178, 412, 1202]     0.062544       0
# 2  [157, 6, 592, 2862, 2185, 445, 1, 148]     0.999407       1
# 3                  [391, 3168, 5935, 104]     0.587871       1
# 4               [457, 574, 21, 400, 1020]     0.999453       1

# %%
# Create a submission file for Kaggle
submission = test_tweet[["id", "target"]]

# Save the submission file
submission.to_csv("submission_GRU.csv", index=False, header=True)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
